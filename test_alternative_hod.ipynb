# %%
import numpy as np
import h5py
import os
from os.path import join
from matplotlib import pyplot as plt

# %%
lhid = 171
path = f'/anvil/scratch/x-mho1/cmass-ili/abacus/nbody/L2000-N256/{lhid}/galaxies'
with h5py.File(join(path, 'hod01711.h5'), 'r') as f:
    zpos = f['0.666667']['pos'][:]
path = f'/anvil/scratch/x-mho1/cmass-ili/abacus/nbody-leauthaud/L2000-N256/{lhid}/galaxies'
with h5py.File(join(path, 'hod01711.h5'), 'r') as f:
    lpos = f['0.666667']['pos'][:]

# %%
len(zpos), len(lpos)
# Out:
# (4315729, 300005)

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 10))
# ax.scatter(zpos[:, 0], zpos[:, 1], s=1, alpha=0.1)
ax.scatter(lpos[:, 0], lpos[:, 1], s=1, alpha=0.1)
