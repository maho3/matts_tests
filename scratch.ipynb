# %%
import os
os.environ['OPENBLAS_NUM_THREADS'] = '16'

import matplotlib.pyplot as plt
import matplotlib as mpl
from pmwd import (
    Configuration,
    Cosmology,
    boltzmann,
    white_noise, linear_modes,
    lpt,
    nbody,
    scatter,
)
import pmwd
import jax
import numpy as np

# %%
L = 3000  # Mpc/h
N = 384  # number of grid points
supersampling = 1
ptcl_spacing = L / N
ptcl_grid_shape = (N,)*3
conf = Configuration(ptcl_spacing, ptcl_grid_shape,
                     mesh_shape=supersampling)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
seed = 12
modes = white_noise(seed, conf)

# %%
M = 512
x = np.random.randn(512, 512, 512)
m = np.fft.rfftn(x)

# %%
y = np.fft.irfftn(m)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(x[0])

# %%
path = './data/borg-quijote/latin_hypercube_HR-L1000-N128/4/rho.npy'
l = np.load(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 path = './data/borg-quijote/latin_hypercube_HR-L1000-N128/4/rho.npy'
# ----> 2 l = np.load(path)
#
# File /data80/mattho/anaconda3/envs/jax/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/borg-quijote/latin_hypercube_HR-L1000-N128/4/rho.npy'

# %%
plt.figure(figsize=(10, 10))
plt.imshow(l[0])

# %%
path = './data/cmass-ili/latin_hypercube_HR-L1000-N128/4/rho.npy'
j = np.load(path)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(j[0])

# %%
path = './data/pmwd-quijote/latin_hypercube_HR-L1000-N128/4/rho.npy'
p = np.load(path)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(p[0])

# %%
path = './data/quijote/source/density_field/latin_hypercube/4/df_m_128_z=0.npy'
r = np.load(path)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(r[0])

# %%
f, axs = plt.subplots(1, 4, figsize=(24, 10), gridspec_kw={'wspace': 0.01})

axs[0].imshow(np.mean(r[50:60], axis=0), vmin=-1, vmax=5)
axs[0].axis('off')
axs[0].set_title('Quijote Nbody')

axs[1].imshow(np.mean(l[50:60], axis=0), vmin=-1, vmax=5)
axs[1].axis('off')
axs[1].set_title('BORG2LPT')

axs[2].imshow(np.mean(j[50:60], axis=0), vmin=-1, vmax=5)
axs[2].axis('off')
axs[2].set_title('jax-2LPT')

axs[3].imshow(np.mean(p[50:60]-1, axis=0), vmin=-1, vmax=5)
axs[3].axis('off')
axs[3].set_title('pmwd')
f.savefig('images/simcompare.jpg', dpi=400, bbox_inches='tight')

# %%
r.min()
# Out:
# -0.9174982

# %% [markdown]
# ## test velocity comparison

# %%
# %load_ext autoreload
# %autoreload 2

import os # noqa
os.environ['OPENBLAS_NUM_THREADS'] = '16' # noqa

from os.path import join as pjoin
import matplotlib.pyplot as plt
import jax
import numpy as np
import pandas as pd

from test import *

# %%
lhs = np.loadtxt('latin_hypercube_params_bonus.txt')[:100]
pd.DataFrame(lhs).head(40)
# Out:
#          0        1       2       3       4
# 0   0.1755  0.06681  0.7737  0.8849  0.6641
# 1   0.2139  0.05557  0.8599  0.9785  0.8619
# 2   0.1867  0.04503  0.6189  0.8307  0.7187
# 3   0.3271  0.06875  0.6313  0.8135  0.8939
# 4   0.1433  0.06347  0.6127  1.1501  0.7699
# 5   0.4813  0.05637  0.5331  0.9041  0.9289
# 6   0.4149  0.04539  0.5761  0.9911  0.6283
# 7   0.2423  0.06275  0.5675  0.8305  0.7145
# 8   0.3215  0.05487  0.6429  1.0531  0.7509
# 9   0.4197  0.05329  0.5265  0.9665  0.6233
# 10  0.1821  0.04809  0.5865  0.9565  0.8101
# 11  0.4195  0.04627  0.7635  1.0415  0.8047
# 12  0.1381  0.05945  0.5939  1.0353  0.8967
# 13  0.2965  0.04883  0.7613  0.9025  0.9441
# 14  0.1327  0.03307  0.7339  1.1413  0.6187
# 15  0.4791  0.06759  0.8131  0.9573  0.7391
# 16  0.2849  0.05533  0.5883  0.9703  0.9863
# 17  0.2475  0.04437  0.7861  0.9407  0.7411
# 18  0.1131  0.05835  0.6561  0.9527  0.8183
# 19  0.4751  0.06443  0.7669  1.1375  0.9131
# ...

# %%
lhid=10
datadir = f'../data/pmwd-quijote/latin_hypercube_HR-L3000-N384/{lhid}'
rho = np.load(pjoin(datadir, 'rho.npy'))
ppos = np.load(pjoin(datadir, 'ppos.npy'))
pvel = np.load(pjoin(datadir, 'pvel.npy'))
hpos = np.load(pjoin(datadir, 'halo_pos.npy'))
hvel = np.load(pjoin(datadir, 'halo_vel.npy'))

ppos = ppos[::]
pvel = pvel[::]

print(rho.shape)
print(ppos.shape)
print(pvel.shape)
print(hpos.shape)
print(hvel.shape)

cosmo = np.loadtxt('../data/quijote/source/latin_hypercube_params_bonus.txt')[lhid]
omega_m = cosmo[0]
print(cosmo)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 6
#       4 ppos = np.load(pjoin(datadir, 'ppos.npy'))
#       5 pvel = np.load(pjoin(datadir, 'pvel.npy'))
# ----> 6 hpos = np.load(pjoin(datadir, 'halo_pos.npy'))
#       7 hvel = np.load(pjoin(datadir, 'halo_vel.npy'))
#       9 ppos = ppos[::]
#
# File /data80/mattho/anaconda3/envs/jax/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/pmwd-quijote/latin_hypercube_HR-L3000-N384/10/halo_pos.npy'

# %%
from pmwd import Configuration, Cosmology

# Set manually
L = 3000  # Mpc/h
N = 384  # number of grid points
supersampling = 1
ptcl_spacing = L / N
ptcl_grid_shape = (N,)*3
conf = Configuration(ptcl_spacing, ptcl_grid_shape,
                        mesh_shape=supersampling)
cosmo = Cosmology.from_sigma8(
    conf, cosmo[4], n_s=cosmo[3], Omega_m=cosmo[0],
    Omega_b=cosmo[1], h=cosmo[2])

# %%
prefactor = L * cosmo.h * 100

prefactor*pvel.min(axis=0), prefactor*pvel.max(axis=0)
# Out:
# (array([-52123.156, -49844.164, -48448.883], dtype=float32),
#  array([44144.574, 45483.938, 48223.285], dtype=float32))

# %%
pvel.min(axis=0), pvel.max(axis=0)
# Out:
# (array([-2026.327, -1874.442, -1910.376]),
#  array([1844.316, 1759.317, 1855.869]))

# %%
vgrid = get_vgrid(rho, jnp.int64(3000), 9., f=omega_m ** 0.45)
vnorm = np.linalg.norm(vgrid, axis=0)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# plot a slice of rho and vnorm
f, axs = plt.subplots(1, 2, figsize=(13, 5))
axs[0].imshow(np.mean(rho[100:120, :100, :100], axis=0))
im = axs[1].imshow(np.mean(vnorm[100:120, :100, :100], axis=0))
plt.colorbar(im)

# %%
origin = [3000,]*3
halo_v = interp_field(vgrid,
                      hpos,
                      jnp.int64(3000),
                      origin,
                      order=1
                      )
field_v = halo_v.T[:10000]

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=6, leaf_size=1000,
                          algorithm='ball_tree', weights='distance', n_jobs=-1)
knn.fit(ppos, pvel)
# Out:
# KNeighborsRegressor(algorithm='ball_tree', leaf_size=1000, n_jobs=-1,
#                     n_neighbors=6, weights='distance')

# %%
knn_v = knn.predict(hpos[:10000])

# %%
import seaborn as sns
import pandas as pd

a = np.linalg.norm(knn_v, axis=1)
b = np.linalg.norm(field_v, axis=1)

# create a pandas dataframe
df = pd.DataFrame({'v_KNN': a, 'v_field': b})

# create a jointplot
f, ax = plt.subplots(figsize=(6, 6))
ax.plot([0,1200], [0,1200], 'k--')
jp = sns.regplot(data=df, x='v_KNN', y='v_field', ax=ax,
                 scatter_kws={'s': 1, 'alpha': 0.5},
                 line_kws={'color': 'red'})

ax.set_xlim(0, 1200)
ax.set_ylim(0, 1400)
ax.set_title(f'$\Omega_m = {cosmo[0]}$, '
             f'$\Omega_b = {cosmo[1]}$, '
             f'$h = {cosmo[2]}$, '
             f'$n_s = {cosmo[3]}$, '
             f'$\sigma_8 = {cosmo[4]}$',
             fontsize=10
             )
# Out:
# Text(0.5, 1.0, '$\\Omega_m = 0.3215$, $\\Omega_b = 0.05487$, $h = 0.6429$, $n_s = 1.0531$, $\\sigma_8 = 0.7509$')

# %%
# regress a,b and print the coefficient

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(a.reshape(-1,1),b)
print(lr.coef_)
# Out:
# [0.65308759]

# %%
import tqdm

# coefs = []
# oms = []
for lhid in tqdm.tqdm(range(30, 60)):
    datadir = f'./data/borg-quijote/latin_hypercube_HR-L3000-N384/{lhid}'
    rho = np.load(pjoin(datadir, 'rho.npy'))
    ppos = np.load(pjoin(datadir, 'ppos.npy'))
    pvel = np.load(pjoin(datadir, 'pvel.npy'))
    hpos = np.load(pjoin(datadir, 'halo_pos.npy'))

    ppos = ppos[::500]
    pvel = pvel[::500]

    cosmo = np.loadtxt('latin_hypercube_params_bonus.txt')[lhid]
    omega_m = cosmo[0]
    print(lhid, cosmo)

    # vfield
    vgrid = get_vgrid(rho, jnp.int64(3000), 9., f=omega_m ** 0.55)
    vnorm = np.linalg.norm(vgrid, axis=0)
    origin = [3000,]*3
    halo_v = interp_field(vgrid,
                        hpos,
                        jnp.int64(3000),
                        origin,
                        order=1
                        )
    field_v = halo_v.T[:10000]

    # vknn
    knn = KNeighborsRegressor(n_neighbors=6, leaf_size=1000,
                            algorithm='ball_tree', weights='distance', n_jobs=-1)
    knn.fit(ppos, pvel)
    knn_v = knn.predict(hpos[:10000])

    a = np.linalg.norm(knn_v, axis=1)
    b = np.linalg.norm(field_v, axis=1)
    lr = LinearRegression()
    lr.fit(a.reshape(-1,1),b)

    coefs.append(lr.coef_)
    oms.append(omega_m)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 30 [0.1931  0.06181 0.8337  1.0579  0.6263 ]
# /data80/mattho/anaconda3/envs/jax/lib/python3.11/site-packages/jax/_src/numpy/lax_numpy.py:146: UserWarning: Explicitly requested dtype int64 requested in asarray is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   return asarray(x, dtype=self.dtype)
#   3%|▎         | 1/30 [00:52<25:26, 52.65s/it]
# 31 [0.4083  0.03347 0.6471  1.1835  0.9961 ]
# ...

# %%
# plot om and coefs
plt.loglog()
plt.plot(oms, coefs, 'mo')

lr = LinearRegression().fit(np.log(oms).reshape(-1, 1), np.log(coefs))
print(lr.coef_[0])
print(lr.intercept_)

plt.plot(oms, np.exp(lr.intercept_) * oms**lr.coef_[0], 'k-')
# Out:
# [-0.36570014]
# [-0.66465479]

# %% [markdown]
# $$f = \Omega_m^{0.55}$$
# $$v_{field} \propto C f v_{true}$$
# $$v_{field} = m v_{true}$$
# \log m = D \log \Omega_m

# %%
0.55-0.36
# Out:
# 0.19000000000000006

# %% [markdown]
# ## fix pmwd

# %%
# %load_ext autoreload
# %autoreload 2

import os # noqa
os.environ['OPENBLAS_NUM_THREADS'] = '16' # noqa

from os.path import join as pjoin
import matplotlib.pyplot as plt
import jax
import numpy as np
import pandas as pd

from test import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
lhid=6
L, N = 3000, 384

datadir = f'../data/pmwd/L{L}-N{N}/{lhid}'
prho = np.load(pjoin(datadir, 'rho.npy'))
ppos = np.load(pjoin(datadir, 'ppos.npy'))
pvel = np.load(pjoin(datadir, 'pvel.npy'))

datadir = f'../data/borg2lpt/L{L}-N{N}/{lhid}'
lrho = np.load(pjoin(datadir, 'rho.npy'))
lpos = np.load(pjoin(datadir, 'ppos.npy'))
lvel = np.load(pjoin(datadir, 'pvel.npy'))

cosmo = np.loadtxt('../data/quijote/source/latin_hypercube_params_bonus.txt')[lhid]
omega_m = cosmo[0]
print(cosmo)
# Out:
# [0.415 0.045 0.576 0.991 0.628]

# %%
ppos.min(), ppos.max(), lpos.min(), lpos.max()
# Out:
# (1.1444091796875e-05,
#  2999.9999957084656,
#  3.9011049741799475e-05,
#  2999.9999784753904)

# %%
f, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(np.mean(prho[50:60], axis=0), vmin=-1, vmax=5)
axs[1].imshow(np.mean(lrho[50:60], axis=0), vmin=-1, vmax=5)

# %%
plt.hist(np.log10(np.abs(prho - lrho) / (lrho+1)).flatten(), range=(-5,0), bins=100)
plt.show()
# Out:
# /tmp/ipykernel_728369/1504819635.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.hist(np.log10(np.abs(prho - lrho) / (lrho+1)).flatten(), range=(-5,0), bins=100)

# %%
from pmwd import Configuration, Cosmology

# Set manually
# L = 3000  # Mpc/h
# N = 64  # number of grid points
supersampling = 1
ptcl_spacing = L / N
ptcl_grid_shape = (N,)*3
conf = Configuration(ptcl_spacing, ptcl_grid_shape,
                        mesh_shape=supersampling)
cosmo = Cosmology.from_sigma8(
    conf, cosmo[4], n_s=cosmo[3], Omega_m=cosmo[0],
    Omega_b=cosmo[1], h=cosmo[2])

# %%
lnorm = np.linalg.norm(lvel, axis=1)
pnorm = np.linalg.norm(pvel, axis=1)


prefactor = 100 # 2*(100*cosmo.h.item())

f = plt.figure(figsize=(8,4))
plt.hist(lnorm, bins=100, alpha=0.5, label='LPT')
plt.hist(prefactor*pnorm, bins=100, alpha=0.5, label='PM')
plt.legend()
plt.xlabel('|v| [km/s]')

# lvel.std(axis=0), prefactor*pvel.std(axis=0)
plt.show()

# %%
import tqdm
prefactor = 100 # (100*cosmo.h.item())

def vfield_NGP(ppos, pvel, sample=1):
    if sample < 1:
        mask = np.random.rand(len(ppos)) < sample
        ppos = ppos[mask]
        pvel = pvel[mask]

    n = N//8
    rhogrid = np.zeros((n, n, n))
    momgrid = np.zeros((3, n, n, n))

    for i in tqdm.tqdm(range(len(ppos))):
        inds = (ppos[i]*n/L) // 1 # NGP
        inds = inds.astype(int)
        rhogrid[inds[0], inds[1], inds[2]] += 1
        momgrid[:,inds[0], inds[1], inds[2]] += pvel[i]
    vgrid = (momgrid/rhogrid[None, ...])
    return vgrid

pvngp = vfield_NGP(ppos, pvel, sample=0.05)
lvngp = vfield_NGP(lpos, lvel, sample=0.05)
# Out:
# ...
# 100%|██████████| 2832131/2832131 [00:27<00:00, 104764.85it/s]

# %%
f, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(np.linalg.norm(pvngp[:,:,0], axis=0))
axs[1].imshow(np.linalg.norm(lvngp[:,:,0], axis=0))

axs[0].set_title('|v| PMWD 2LPT NGP')
axs[1].set_title('|v| BORG2LPT NGP')
# Out:
# Text(0.5, 1.0, '|v| BORG2LPT NGP')

# %%
x_ = np.linalg.norm(pvngp, axis=0).flatten()
y_ = np.linalg.norm(lvngp, axis=0).flatten()
mask = np.random.rand(len(x_)) < 0.01

plt.figure(figsize=(4, 4))
x11 = np.linspace(0, 1000, 100)
plt.plot(x11, x11, 'k--')
plt.plot(x_[mask]*prefactor, y_[mask], '.', alpha=0.1)
plt.xlabel('|v| PMWD 2LPT NGP')
plt.ylabel('|v| BORG2LPT NGP')
plt.xlim(0, 1000)
plt.ylim(0, 1000)
plt.gca().set_aspect('equal')

# %%
from pmwd import (
    Configuration,
    Cosmology,
    boltzmann,
    linear_modes,
    lpt,
    scatter,
)
content = # load cosmo params from file
modes = # load white noise IC from file

# Set manually
L = 3000  # Mpc/h
N = 384  # number of grid points
supersampling = 1
ptcl_spacing = L / N
ptcl_grid_shape = (N,)*3
conf = Configuration(ptcl_spacing, ptcl_grid_shape,
                        a_start=1., a_nbody_num=0,
                        mesh_shape=supersampling)
cosmo = Cosmology.from_sigma8(
    conf, sigma8=content[4], n_s=content[3], Omega_m=content[0],
    Omega_b=content[1], h=content[2])

# calculate ICs with EH
cosmo = boltzmann(cosmo, conf)
ic = linear_modes(modes, cosmo, conf)

# Run LPT
ptcl, obsvbl = lpt(ic, cosmo, conf)

# Save
rho = scatter(ptcl, conf)
pos = np.array(ptcl.pos())
vel = ptcl.vel

rho -= 1 # density contrast
vel *= 100 * cosmo.h  # km/s
# Out:
# array([[-1.561, -3.599, 13.355],
#        [-1.873, -4.397,  8.632],
#        ...,
#        [ 2.661, -0.928, 16.745],
#        [ 2.148, -2.606, 18.146]], dtype=float32)

# %% [markdown]
# # Check pmwd scatter

# %%
import numpy as np
import matplotlib.pyplot as plt
from pmwd import Configuration, Particles, scatter

# %%
384**3/1000000
# Out:
# 56.623104

# %%
pos = np.random.rand(384**3,3)*3000

# %%
L = 3000
N = 384
ptcl_spacing = L / N
ptcl_grid_shape = (N,)*3
pmconf = Configuration(ptcl_spacing, ptcl_grid_shape)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
smooth = 32
mesh = np.zeros([N//smooth]*3)
ptcl = Particles.from_pos(pmconf, pos)
rho = scatter(ptcl, pmconf, val=1, mesh=mesh)

# %%
rho.shape
# Out:
# (12, 12, 12)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(rho[:,:,0])
plt.colorbar()

# %% [markdown]
# ## Check weird halo biasing behavior

# %%
# %load_ext autoreload
# %autoreload 2

from cmass.bias.fit_halo_bias import load_quijote_halos, TruncatedPowerLaw, OmegaConf
import numpy as np
import matplotlib.pyplot as plt

# %%
L = 1000
N, Nm = 128, 10
mmin, mmax = 12.8, 15.8
snapdir = '../data/quijote/source/Halos/latin_hypercube_HR/3'

# load quijote halos and compute histogram
pos_h, mass, _, _ = load_quijote_halos(snapdir)
posm = np.concatenate([pos_h, np.log10(mass)[:, None]], axis=1)
h, edges = np.histogramdd(
    posm,
    (N,)*3+(Nm,),
    range=[(0, L)]*3+[(mmin, mmax)]
)

rho_path = '/home/mattho/git/ltu-cmass/data/calib_1gpch/pmwd/L1000-N128/3/rho.npy'
rho = np.load(rho_path)

# %%
f, axs = plt.subplots(5,2)
axs = axs.flatten()
for i in range(10):
    x_ = rho.flatten()
    y_ = h[...,i].flatten()
    mask = np.random.rand(len(x_)) < 0.01
    axs[i].plot(x_[mask], y_[mask], '.', alpha=0.1)

# %%
np.sum(h[...,0])
# Out:
# 349200.0

# %%
law = TruncatedPowerLaw()
popt = law.fit(rho, h[...,-1])
print(popt)
# Out:
# /home/mattho/git/ltu-cmass/cmass/bias/tools/halos.py:78: RuntimeWarning: divide by zero encountered in log
#   loss = ngal_mean - count_field * np.log(ngal_mean)
# /home/mattho/git/ltu-cmass/cmass/bias/tools/halos.py:78: RuntimeWarning: invalid value encountered in multiply
#   loss = ngal_mean - count_field * np.log(ngal_mean)
# /home/mattho/git/ltu-cmass/cmass/bias/tools/halos.py:68: RuntimeWarning: divide by zero encountered in divide
#   x = np.power(np.abs(d / rho_g), -epsilon_g)
# [8.773e-07 2.949e+00 1.384e-03 0.000e+00]

# %%
out = [np.sum(law.sample(rho, popt)) for _ in range(100)]
plt.hist(out, bins=10)
plt.axvline(np.sum(h[...,-1]), color='r')
# Out:
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# 1.8413479e-24 1.8413479e-24
# ...

# %%
np.sum(h[...,3])
# Out:
# 48897.0

# %%
# Out:
# 3759.0

# %%
law.fit(rho, h[...,5])
# Out:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 0.02481553429423243
#              x: [ 8.534e-03  1.661e+00  8.089e-06  2.192e+00]
#            nit: 119
#           nfev: 221
#  final_simplex: (array([[ 8.534e-03,  1.661e+00,  8.089e-06,  2.192e+00],
#                        [ 8.534e-03,  1.661e+00,  8.083e-06,  2.192e+00],
#                        ...,
#                        [ 8.535e-03,  1.661e+00,  8.078e-06,  2.192e+00],
#                        [ 8.535e-03,  1.661e+00,  8.113e-06,  2.192e+00]]), array([ 2.482e-02,  2.482e-02,  2.482e-02,  2.482e-02,
#                         2.482e-02]))

# %%
rho.min()
# Out:
# -0.9999969
